# %%
import pandas as pd
import numpy as np
#from sklearn import preprocessing
from sklearn.preprocessing import scale , normalize , minmax_scale

# %%
data = pd.read_csv(r'heart-statlog.csv', encoding=('ansi'))

# %%
data
# Out:
#      age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0     70    1      4                     130                322
# 1     67    0      3                     115                564
# 2     57    1      2                     124                261
# 3     64    1      4                     128                263
# 4     74    0      2                     120                269
# ..   ...  ...    ...                     ...                ...
# 265   52    1      3                     172                199
# 266   44    1      2                     120                263
# 267   56    0      2                     140                294
# 268   57    1      4                     140                192
# 269   67    1      4                     160                286
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                      0                                     2
# 1                      0                                     2
# ...

# %%
data.shape
# Out:
# (270, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest                                 270 non-null    int64
#  3   resting_blood_pressure                270 non-null    int64
#  4   serum_cholestoral                     270 non-null    int64
#  5   fasting_blood_sugar                   270 non-null    int64
#  6   resting_electrocardiographic_results  270 non-null    int64
#  7   maximum_heart_rate_achieved           270 non-null    int64
#  8   exercise_induced_angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  slope                                 270 non-null    int64
# ...

# %%
data.describe()
# Out:
#               age         sex       chest  resting_blood_pressure  \
# count  270.000000  270.000000  270.000000              270.000000
# mean    54.433333    0.677778    3.174074              131.344444
# std      9.109067    0.468195    0.950090               17.861608
# min     29.000000    0.000000    1.000000               94.000000
# 25%     48.000000    0.000000    3.000000              120.000000
# 50%     55.000000    1.000000    3.000000              130.000000
# 75%     61.000000    1.000000    4.000000              140.000000
# max     77.000000    1.000000    4.000000              200.000000
#
#        serum_cholestoral  fasting_blood_sugar  \
# count         270.000000           270.000000
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# 50%           245.000000             0.000000
# ...

# %%
data.isnull().sum()
# Out:
# age                                     0
# sex                                     0
# chest                                   0
# resting_blood_pressure                  0
# serum_cholestoral                       0
# fasting_blood_sugar                     0
# resting_electrocardiographic_results    0
# maximum_heart_rate_achieved             0
# exercise_induced_angina                 0
# oldpeak                                 0
# slope                                   0
# number_of_major_vessels                 0
# thal                                    0
# class                                   0
# dtype: int64

# %%
data.dropna(axis=0)
# Out:
#      age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0     70    1      4                     130                322
# 1     67    0      3                     115                564
# 2     57    1      2                     124                261
# 3     64    1      4                     128                263
# 4     74    0      2                     120                269
# ..   ...  ...    ...                     ...                ...
# 265   52    1      3                     172                199
# 266   44    1      2                     120                263
# 267   56    0      2                     140                294
# 268   57    1      4                     140                192
# 269   67    1      4                     160                286
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                      0                                     2
# 1                      0                                     2
# ...

# %%
data_max = data["serum_cholestoral"].max()

# %%
data["serum_cholestoral"][data["serum_cholestoral"]==data_max]
# Out:
# 1    564
# Name: serum_cholestoral, dtype: int64

# %%
data.drop_duplicates()
# Out:
#      age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0     70    1      4                     130                322
# 1     67    0      3                     115                564
# 2     57    1      2                     124                261
# 3     64    1      4                     128                263
# 4     74    0      2                     120                269
# ..   ...  ...    ...                     ...                ...
# 265   52    1      3                     172                199
# 266   44    1      2                     120                263
# 267   56    0      2                     140                294
# 268   57    1      4                     140                192
# 269   67    1      4                     160                286
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                      0                                     2
# 1                      0                                     2
# ...

# %%
data12 = data.drop('serum_cholestoral' , axis=1 )

# %%
cat = data.groupby(data['class'])

# %%
cat.min)
# Out:
#                age       sex     chest  resting_blood_pressure  \
# class
# absent   52.706667  0.553333  2.820000              128.866667
# present  56.591667  0.833333  3.616667              134.441667
#
#          serum_cholestoral  fasting_blood_sugar  \
# class
# absent          244.213333             0.153333
# present         256.466667             0.141667
#
#          resting_electrocardiographic_results  maximum_heart_rate_achieved  \
# class
# absent                                  0.860                   158.333333
# present                                 1.225                   138.858333
#
#          exercise_induced_angina   oldpeak     slope  number_of_major_vessels  \
# class
# absent                  0.153333  0.622667  1.400000                 0.286667
# present                 0.550000  1.584167  1.816667                 1.150000
#
#              thal
# class
# absent   3.786667
# present  5.833333

# %%
data.drop('class' , axis=1 )
# Out:
#      age  sex  chest  resting_blood_pressure  serum_cholestoral  \
# 0     70    1      4                     130                322
# 1     67    0      3                     115                564
# 2     57    1      2                     124                261
# 3     64    1      4                     128                263
# 4     74    0      2                     120                269
# ..   ...  ...    ...                     ...                ...
# 265   52    1      3                     172                199
# 266   44    1      2                     120                263
# 267   56    0      2                     140                294
# 268   57    1      4                     140                192
# 269   67    1      4                     160                286
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# 0                      0                                     2
# 1                      0                                     2
# ...

# %%
data1 = data.drop('class' , axis=1 )
scale_data = scale(data1)
df_data = pd.DataFrame(scale_data,index=data1.index,columns=data1.columns)

# %%
df_data
# Out:
#           age       sex     chest  resting_blood_pressure  serum_cholestoral  \
# 0    1.712094  0.689500  0.870928               -0.075410           1.402212
# 1    1.382140 -1.450327 -0.183559               -0.916759           6.093004
# 2    0.282294  0.689500 -1.238045               -0.411950           0.219823
# 3    1.052186  0.689500  0.870928               -0.187590           0.258589
# 4    2.152032 -1.450327 -1.238045               -0.636310           0.374890
# ..        ...       ...       ...                     ...                ...
# 265 -0.267629  0.689500 -0.183559                2.280369          -0.981951
# 266 -1.147506  0.689500 -1.238045               -0.636310           0.258589
# 267  0.172309 -1.450327 -1.238045                0.485490           0.859476
# 268  0.282294  0.689500  0.870928                0.485490          -1.117635
# 269  1.382140  0.689500  0.870928                1.607289           0.704409
#
# ...

# %%
normalize_data = normalize(data1, norm='l2' , axis=0) 
df_data = pd.DataFrame(normalize_data,
                       index=data1.index,
                       columns=data1.columns
                       )

# %%
df_data
# Out:
#           age       sex     chest  resting_blood_pressure  serum_cholestoral  \
# 0    0.077193  0.073922  0.073484                0.059688           0.076868
# 1    0.073884  0.000000  0.055113                0.052801           0.134639
# 2    0.062857  0.073922  0.036742                0.056933           0.062306
# 3    0.070576  0.073922  0.073484                0.058769           0.062784
# 4    0.081604  0.000000  0.036742                0.055096           0.064216
# ..        ...       ...       ...                     ...                ...
# 265  0.057343  0.073922  0.055113                0.078971           0.047505
# 266  0.048521  0.073922  0.036742                0.055096           0.062784
# 267  0.061754  0.000000  0.036742                0.064279           0.070184
# 268  0.062857  0.073922  0.073484                0.064279           0.045834
# 269  0.073884  0.073922  0.073484                0.073462           0.068274
#
# ...

# %%
normalize_data = normalize(data1, norm='l1' , axis=0) 
df_data = pd.DataFrame(normalize_data,
                       index=data1.index,
                       columns=data1.columns
                       )

# %%
df_data
# Out:
#           age       sex     chest  resting_blood_pressure  serum_cholestoral  \
# 0    0.004763  0.005464  0.004667                0.003666           0.004777
# 1    0.004559  0.000000  0.003501                0.003243           0.008367
# 2    0.003878  0.005464  0.002334                0.003497           0.003872
# 3    0.004355  0.005464  0.004667                0.003609           0.003902
# 4    0.005035  0.000000  0.002334                0.003384           0.003991
# ..        ...       ...       ...                     ...                ...
# 265  0.003538  0.005464  0.003501                0.004850           0.002952
# 266  0.002994  0.005464  0.002334                0.003384           0.003902
# 267  0.003810  0.000000  0.002334                0.003948           0.004362
# 268  0.003878  0.005464  0.004667                0.003948           0.002848
# 269  0.004559  0.005464  0.004667                0.004512           0.004243
#
# ...

# %%
minmax_data = minmax_scale(data1, feature_range=(0,1) ) #euclidean norm
df_data = pd.DataFrame(minmax_data,
                       index=data1.index,
                       columns=data1.columns
                       )

# %%
df_data
# Out:
#           age  sex     chest  resting_blood_pressure  serum_cholestoral  \
# 0    0.854167  1.0  1.000000                0.339623           0.447489
# 1    0.791667  0.0  0.666667                0.198113           1.000000
# 2    0.583333  1.0  0.333333                0.283019           0.308219
# 3    0.729167  1.0  1.000000                0.320755           0.312785
# 4    0.937500  0.0  0.333333                0.245283           0.326484
# ..        ...  ...       ...                     ...                ...
# 265  0.479167  1.0  0.666667                0.735849           0.166667
# 266  0.312500  1.0  0.333333                0.245283           0.312785
# 267  0.562500  0.0  0.333333                0.433962           0.383562
# 268  0.583333  1.0  1.000000                0.433962           0.150685
# 269  0.791667  1.0  1.000000                0.622642           0.365297
#
#      fasting_blood_sugar  resting_electrocardiographic_results  \
# ...
